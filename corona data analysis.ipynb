# %% [markdown]
# # Corona Data Analysis

# %% [markdown]
# ## Workflow :

# %% [markdown]
# ## Importing required library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading the Data Set

# %%
data=pd.read_csv("C:\\Users\\ritik\\Downloads\\datasets-20221227T153602Z-001\\datasets\\data sets\\latest Covid-19 India Status1.csv")

# %% [markdown]
# ## Viewing the Data

# %%
data.head()
# Out:
#         State/UTs  Total Cases  Active  Deaths  Active Ratio (%)  \
# 0     Maharashtra      6122893  117869  123857              1.93
# 1          Kerala      3011694  108400   14108              3.60
# 2       Karnataka      2862338   39626   35601              1.38
# 3      Tamil Nadu      2506848   34076   33196              1.36
# 4  Andhra Pradesh      1911231   32356   12919              1.69
#
#    Death Ratio (%)
# 0             2.02
# 1             0.47
# 2             1.24
# 3             1.32
# 4             0.68

# %%
data.sample(10)
# Out:
#                                    State/UTs  Total Cases  Active  Deaths  \
# 18                                 Jharkhand       346113     532    5118
# 33  Dadra and Nagar Haveli and Daman and Diu        10576      38       4
# 14                                     Bihar       722850    1183    9612
# 24                                   Manipur        74341    6534    1229
# 15                                 Telengana       629054   11472    3710
# 2                                  Karnataka      2862338   39626   35601
# 17                                     Assam       524556   23371    4743
# 13                                   Haryana       769093    1066    9515
# 1                                     Kerala      3011694  108400   14108
# 29                                  Nagaland        25663    1070     505
#
#     Active Ratio (%)  Death Ratio (%)
# 18              0.15             1.48
# 33              0.36             0.04
# ...

# %%
data.tail()
# Out:
#                                    State/UTs  Total Cases  Active  Deaths  \
# 31                                    Sikkim        21573    1975     311
# 32                                    Ladakh        20143     183     204
# 33  Dadra and Nagar Haveli and Daman and Diu        10576      38       4
# 34                               Lakshadweep         9965     246      49
# 35                       Andaman and Nicobar         7491      14     128
#
#     Active Ratio (%)  Death Ratio (%)
# 31              9.15             1.44
# 32              0.91             1.01
# 33              0.36             0.04
# 34              2.47             0.49
# 35              0.19             1.71

# %% [markdown]
# ## Checking the shape of data

# %%
data.shape    ## checking the rows and columns in the data
# Out:
# (36, 6)

# %% [markdown]
# ## Checking the data type

# %%
data.dtypes
# Out:
# State/UTs            object
# Total Cases           int64
# Active                int64
# Deaths                int64
# Active Ratio (%)    float64
# Death Ratio (%)     float64
# dtype: object

# %% [markdown]
# ## Column Name

# %%
data.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Deaths', 'Active Ratio (%)',
#        'Death Ratio (%)'],
#       dtype='object')

# %% [markdown]
# ## Basic Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UTs         36 non-null     object
#  1   Total Cases       36 non-null     int64
#  2   Active            36 non-null     int64
#  3   Deaths            36 non-null     int64
#  4   Active Ratio (%)  36 non-null     float64
#  5   Death Ratio (%)   36 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.8+ KB

# %% [markdown]
# ## Checking the missing value

# %%
data.isnull().sum()
# Out:
# State/UTs           0
# Total Cases         0
# Active              0
# Deaths              0
# Active Ratio (%)    0
# Death Ratio (%)     0
# dtype: int64

# %% [markdown]
# ## Find the total cases of each state

# %%
k=data.groupby(["State/UTs"])["Total Cases"].agg(["max","sum","min","mean"]).sort_values(by="max",ascending=False)
k.reset_index(inplace=True)

# %%
k
# Out:
#                                    State/UTs      max      sum      min  \
# 0                                Maharashtra  6122893  6122893  6122893
# 1                                     Kerala  3011694  3011694  3011694
# 2                                  Karnataka  2862338  2862338  2862338
# 3                                 Tamil Nadu  2506848  2506848  2506848
# 4                             Andhra Pradesh  1911231  1911231  1911231
# 5                              Uttar Pradesh  1706934  1706934  1706934
# 6                                West Bengal  1508223  1508223  1508223
# 7                                      Delhi  1434780  1434780  1434780
# 8                               Chhattisgarh   996689   996689   996689
# 9                                  Rajasthan   952887   952887   952887
# 10                                    Odisha   929788   929788   929788
# 11                                   Gujarat   824029   824029   824029
# ...

# %% [markdown]
# ## Find the total case of each state

# %%
sns.barplot(x="State/UTs",y="Total Cases",data=data)
plt.xticks(rotation=90);

# %% [markdown]
# - deadly effected is maharashtra
# - least effected is andaman nicobar

# %% [markdown]
# ## See the distribusition of each state with respect to total case

# %%
plt.pie(data["Total Cases"],labels=data["State/UTs"],autopct="%0.02f%%");

# %%
df1=data.sort_values(by="Total Cases",ascending=False)
top=df1.head(10)
top
# Out:
#         State/UTs  Total Cases  Active  Deaths  Active Ratio (%)  \
# 0     Maharashtra      6122893  117869  123857              1.93
# 1          Kerala      3011694  108400   14108              3.60
# 2       Karnataka      2862338   39626   35601              1.38
# 3      Tamil Nadu      2506848   34076   33196              1.36
# 4  Andhra Pradesh      1911231   32356   12919              1.69
# 5   Uttar Pradesh      1706934    1947   22666              0.11
# 6     West Bengal      1508223   16655   17850              1.10
# 7           Delhi      1434780     858   25005              0.06
# 8    Chhattisgarh       996689    5017   13464              0.50
# 9       Rajasthan       952887     935    8942              0.10
#
#    Death Ratio (%)
# 0             2.02
# 1             0.47
# 2             1.24
# 3             1.32
# 4             0.68
# 5             1.33
# 6             1.18
# 7             1.74
# 8             1.35
# 9             0.94

# %%
plt.pie(top["Total Cases"],labels=top["State/UTs"],autopct="%0.02f%%");

# %%
## make bar
sns.barplot(x="State/UTs",y="Total Cases",data=top)
plt.xticks(rotation=90);

# %% [markdown]
# ## Find bottom 10 state make pie chart and bar plot

# %%
df2=data.sort_values(by="Total Cases",ascending=False)
bottom=df2.tail(10)
bottom
# Out:
#                                    State/UTs  Total Cases  Active  Deaths  \
# 26                                Chandigarh        61780      99     809
# 27                                 Meghalaya        52712    4229     886
# 28                         Arunachal Pradesh        38283    3363     184
# 29                                  Nagaland        25663    1070     505
# 30                                   Mizoram        22703    3960     100
# 31                                    Sikkim        21573    1975     311
# 32                                    Ladakh        20143     183     204
# 33  Dadra and Nagar Haveli and Daman and Diu        10576      38       4
# 34                               Lakshadweep         9965     246      49
# 35                       Andaman and Nicobar         7491      14     128
#
#     Active Ratio (%)  Death Ratio (%)
# 26              0.16             1.31
# 27              8.02             1.68
# ...

# %%
plt.pie(bottom["Total Cases"],labels=bottom["State/UTs"],autopct="%0.02f%%");

# %% [markdown]
# ## To male barplot of bottom 10 infectetd state

# %%
sns.barplot(x="State/UTs",y="Total Cases",data=bottom)
plt.xticks(rotation=90);

# %% [markdown]
# ## Find the top 10 states which have high active cases

# %%
df3=data.groupby(["State/UTs"])["Active"].max().sort_values(ascending=False).head(10)
df3
# Out:
# State/UTs
# Maharashtra          117869
# Kerala               108400
# Karnataka             39626
# Jammu and Kashmir     34391
# Tamil Nadu            34076
# Andhra Pradesh        32356
# Odisha                25148
# Assam                 23371
# West Bengal           16655
# Telengana             11472
# Name: Active, dtype: int64

# %% [markdown]
# ## Find the top 10 ststes which have highest deadth cases

# %%
data.groupby(["State/UTs"])["Deaths"].max().sort_values(ascending=False).head(10)
# Out:
# State/UTs
# Maharashtra       123857
# Karnataka          35601
# Tamil Nadu         33196
# Delhi              25005
# Uttar Pradesh      22666
# West Bengal        17850
# Punjab             16141
# Kerala             14108
# Chhattisgarh       13464
# Andhra Pradesh     12919
# Name: Deaths, dtype: int64

# %%
data["recovered_cases"]=data['Total Cases']-(data['Active']+data['Deaths'])

# %%
data.head()
# Out:
#         State/UTs  Total Cases  Active  Deaths  Active Ratio (%)  \
# 0     Maharashtra      6122893  117869  123857              1.93
# 1          Kerala      3011694  108400   14108              3.60
# 2       Karnataka      2862338   39626   35601              1.38
# 3      Tamil Nadu      2506848   34076   33196              1.36
# 4  Andhra Pradesh      1911231   32356   12919              1.69
#
#    Death Ratio (%)  recovered_cases
# 0             2.02          5881167
# 1             0.47          2889186
# 2             1.24          2787111
# 3             1.32          2439576
# 4             0.68          1865956

# %% [markdown]
# ## In which state the recovery rate highest and lowest

# %%
data.groupby(["State/UTs"])["recovered_cases"].max().sort_values(ascending=False).head()
# Out:
# State/UTs
# Maharashtra       5881167
# Kerala            2889186
# Karnataka         2787111
# Tamil Nadu        2439576
# Andhra Pradesh    1865956
# Name: recovered_cases, dtype: int64

# %% [markdown]
# ## Find the top 5 recoverd state

# %%
data1=data.sort_values(by="recovered_cases",ascending=False)
top_re=df3.head()
top_re
# Out:
# State/UTs
# Maharashtra          117869
# Kerala               108400
# Karnataka             39626
# Jammu and Kashmir     34391
# Tamil Nadu            34076
# Name: Active, dtype: int64

# %%
plt.figure(figsize=(10,4))
plt.plot(data['State/UTs'],data['Active'],color='red',marker='o',label="active")
plt.xticks(rotation=90,fontsize=13.5)
plt.yticks(fontsize=13.5);

# %%
plt.figure(figsize=(10,4))
plt.plot(data['State/UTs'],data['Deaths'],color='red',marker='o',label="active")
plt.xticks(rotation=90,fontsize=13.5)
plt.yticks(fontsize=13.5);

# %%
plt.figure(figsize=(10,4))
plt.plot(data['State/UTs'],data['recovered_cases'],color='red',marker='o',label="active")
plt.xticks(rotation=90,fontsize=13.5)
plt.yticks(fontsize=13.5);

# %%
plt.figure(figsize=(10,4))
plt.plot(data['State/UTs'],data['Active'],color='red',marker='o',label="active")
plt.xticks(rotation=90,fontsize=13.5)
plt.yticks(fontsize=13.5)
plt.xlabel('State', fontsize=15)
plt.ylabel('cases', fontsize=15)
plt.title("Line Plot for comparative analysis ",fontsize=15)
plt.plot(data['State/UTs'],data['Deaths'],color='blue',marker='o',label="deaths")
plt.plot(data['State/UTs'],data['recovered_cases'],color='green',marker='o',label="recovered")
plt.legend()
 
plt.show()
